# %%
import folium

latitude = -30.0346
longitude = -51.2177

mapa = folium.Map (location=[latitude,longitude], zoom_start=4)

folium.Marker([latitude, longitude], popup='Porto Alegre, RS, Brasil').add_to(mapa)

latitude = -23.5505
longitude = -46.6333

folium.Marker([latitude, longitude], popup='São Paulo, SP, Brasil').add_to(mapa)

latitude = -22.9068 
longitude = -43.1729

folium.Marker([latitude, longitude], popup='Rio de Janeiro, RS, Brasil').add_to(mapa)

latitude = -25.4290
longitude = -49.2671

folium.Marker([latitude, longitude], popup='Curitiba, PR, Brasil').add_to(mapa)

latitude = -19.9173
longitude = -43.9345

folium.Marker([latitude, longitude], popup='Belo Horizonte, SC, Brasil').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2f2acc84b02521762c08e3ccf52fdfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2f2acc84b02521762c08e3ccf52fdfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2f2acc84b02521762c08e3ccf52fdfc = L.map(
#                 &quot;map_c2f2acc84b02521762c08e3ccf52fdfc&quot;,
#                 {
#                     center: [-30.0346, -51.2177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76a7630b10ea61ee9cc885083cc5e169 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_76a7630b10ea61ee9cc885083cc5e169.addTo(map_c2f2acc84b02521762c08e3ccf52fdfc);
#
#
#             var marker_de25cb8b63488ac329594ad0ee497745 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_c2f2acc84b02521762c08e3ccf52fdfc);
#
#
#         var popup_e3c5611a822a86cff3ae38c2b70be394 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c862b96e941110439148d85ed98cd164 = $(`&lt;div id=&quot;html_c862b96e941110439148d85ed98cd164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_e3c5611a822a86cff3ae38c2b70be394.setContent(html_c862b96e941110439148d85ed98cd164);
#
#
#
#         marker_de25cb8b63488ac329594ad0ee497745.bindPopup(popup_e3c5611a822a86cff3ae38c2b70be394)
#         ;
#
#
#
#
#             var marker_6c36abea1f67c68c64feeb65641e44ec = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_c2f2acc84b02521762c08e3ccf52fdfc);
#
#
#         var popup_871d8af1958f54623cc1638a82798a8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_741a05035f446e7256d8b513a762e328 = $(`&lt;div id=&quot;html_741a05035f446e7256d8b513a762e328&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_871d8af1958f54623cc1638a82798a8c.setContent(html_741a05035f446e7256d8b513a762e328);
#
#
#
#         marker_6c36abea1f67c68c64feeb65641e44ec.bindPopup(popup_871d8af1958f54623cc1638a82798a8c)
#         ;
#
#
#
#
#             var marker_00cce83743014e7030e1ed6d41845f85 = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_c2f2acc84b02521762c08e3ccf52fdfc);
#
#
#         var popup_bb5e5c63ba8309a98309597d00fc00f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c2ac03eecd3f9a3f0bee99c9e46a88e = $(`&lt;div id=&quot;html_2c2ac03eecd3f9a3f0bee99c9e46a88e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_bb5e5c63ba8309a98309597d00fc00f8.setContent(html_2c2ac03eecd3f9a3f0bee99c9e46a88e);
#
#
#
#         marker_00cce83743014e7030e1ed6d41845f85.bindPopup(popup_bb5e5c63ba8309a98309597d00fc00f8)
#         ;
#
#
#
#
#             var marker_7bcc8070f412c1e3ffe6e0c1b768fee1 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_c2f2acc84b02521762c08e3ccf52fdfc);
#
#
#         var popup_ef9acfedb399378bc7db5950950ad8ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e45fb957c2d6a10e42d6d01915bc8d9 = $(`&lt;div id=&quot;html_2e45fb957c2d6a10e42d6d01915bc8d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_ef9acfedb399378bc7db5950950ad8ee.setContent(html_2e45fb957c2d6a10e42d6d01915bc8d9);
#
#
#
#         marker_7bcc8070f412c1e3ffe6e0c1b768fee1.bindPopup(popup_ef9acfedb399378bc7db5950950ad8ee)
#         ;
#
#
#
#
#             var marker_cc472731dc16f74e59614842b8f65033 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_c2f2acc84b02521762c08e3ccf52fdfc);
#
#
#         var popup_61820f52525eb36ea486591108a3bb0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bf7a3e25101d3fb11c679576fa369cb = $(`&lt;div id=&quot;html_0bf7a3e25101d3fb11c679576fa369cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, SC, Brasil&lt;/div&gt;`)[0];
#                 popup_61820f52525eb36ea486591108a3bb0a.setContent(html_0bf7a3e25101d3fb11c679576fa369cb);
#
#
#
#         marker_cc472731dc16f74e59614842b8f65033.bindPopup(popup_61820f52525eb36ea486591108a3bb0a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscre
