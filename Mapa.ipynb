# %%
import folium

latitude = -30.0346
longitude = -51.2177

mapa = folium.Map (location=[latitude,longitude], zoom_start=4)

folium.Marker([latitude, longitude], popup='Porto Alegre, RS, Brasil').add_to(mapa)

latitude = -23.5505
longitude = -46.6333

folium.Marker([latitude, longitude], popup='São Paulo, SP, Brasil').add_to(mapa)

latitude = -22.9068 
longitude = -43.1729

folium.Marker([latitude, longitude], popup='Rio de Janeiro, RS, Brasil').add_to(mapa)

latitude = -25.4290
longitude = -49.2671

folium.Marker([latitude, longitude], popup='Curitiba, PR, Brasil').add_to(mapa)

latitude = -19.9173
longitude = -43.9345

folium.Marker([latitude, longitude], popup='Belo Horizonte, SC, Brasil').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2e092fa66a3dd123c4dd63c7fa88872 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2e092fa66a3dd123c4dd63c7fa88872&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2e092fa66a3dd123c4dd63c7fa88872 = L.map(
#                 &quot;map_a2e092fa66a3dd123c4dd63c7fa88872&quot;,
#                 {
#                     center: [-30.0346, -51.2177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c7f86281f79133add8b37e44950e441 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8c7f86281f79133add8b37e44950e441.addTo(map_a2e092fa66a3dd123c4dd63c7fa88872);
#
#
#             var marker_809e8c6718c9fd5473f52b1a4c525993 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_a2e092fa66a3dd123c4dd63c7fa88872);
#
#
#         var popup_21c9e789c44f5432f681d9f6427d3016 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7aea63f923323b7cad7e07b85a7bfdb5 = $(`&lt;div id=&quot;html_7aea63f923323b7cad7e07b85a7bfdb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_21c9e789c44f5432f681d9f6427d3016.setContent(html_7aea63f923323b7cad7e07b85a7bfdb5);
#
#
#
#         marker_809e8c6718c9fd5473f52b1a4c525993.bindPopup(popup_21c9e789c44f5432f681d9f6427d3016)
#         ;
#
#
#
#
#             var marker_3a1d5d39244cb6f1a905ee66b05d2048 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_a2e092fa66a3dd123c4dd63c7fa88872);
#
#
#         var popup_f8b537458b180f38fbaead7bef5639ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90c24602dcf4d52a5002dfc129c1e5f7 = $(`&lt;div id=&quot;html_90c24602dcf4d52a5002dfc129c1e5f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_f8b537458b180f38fbaead7bef5639ad.setContent(html_90c24602dcf4d52a5002dfc129c1e5f7);
#
#
#
#         marker_3a1d5d39244cb6f1a905ee66b05d2048.bindPopup(popup_f8b537458b180f38fbaead7bef5639ad)
#         ;
#
#
#
#
#             var marker_0d973cef084c991f7fb3b64a49a20a8f = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_a2e092fa66a3dd123c4dd63c7fa88872);
#
#
#         var popup_dc775f1a0905083723ddf636fe603e27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d14797a9d0be10e86a7e90d38893996 = $(`&lt;div id=&quot;html_9d14797a9d0be10e86a7e90d38893996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_dc775f1a0905083723ddf636fe603e27.setContent(html_9d14797a9d0be10e86a7e90d38893996);
#
#
#
#         marker_0d973cef084c991f7fb3b64a49a20a8f.bindPopup(popup_dc775f1a0905083723ddf636fe603e27)
#         ;
#
#
#
#
#             var marker_1f54b2ac8f2a8543eadee7d934931758 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_a2e092fa66a3dd123c4dd63c7fa88872);
#
#
#         var popup_833ade74afc6ef87c9915ea78dbd0a41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_571ffef3e68869b2a3f233a2c12a8e23 = $(`&lt;div id=&quot;html_571ffef3e68869b2a3f233a2c12a8e23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_833ade74afc6ef87c9915ea78dbd0a41.setContent(html_571ffef3e68869b2a3f233a2c12a8e23);
#
#
#
#         marker_1f54b2ac8f2a8543eadee7d934931758.bindPopup(popup_833ade74afc6ef87c9915ea78dbd0a41)
#         ;
#
#
#
#
#             var marker_1f33c017d4239519a77989c1e49334e1 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_a2e092fa66a3dd123c4dd63c7fa88872);
#
#
#         var popup_1e5396ca993771cb00620361a933d210 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51abb3586949a9ee87f2d3dbe0bd391b = $(`&lt;div id=&quot;html_51abb3586949a9ee87f2d3dbe0bd391b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, SC, Brasil&lt;/div&gt;`)[0];
#                 popup_1e5396ca993771cb00620361a933d210.setContent(html_51abb3586949a9ee87f2d3dbe0bd391b);
#
#
#
#         marker_1f33c017d4239519a77989c1e49334e1.bindPopup(popup_1e5396ca993771cb00620361a933d210)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscre
